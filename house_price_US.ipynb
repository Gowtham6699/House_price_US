# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
pip install openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hari\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hari\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hari\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hari\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hari\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hari\anaconda\lib\site-packages)
# ...

# %%
employeement_rate = pd.read_csv("C:\\Users\\HARI\\Downloads\\employeement_rate.csv")
hours_worked = pd.read_csv("C:\\Users\\HARI\\Downloads\\worked_hours.csv")
labour_force=pd.read_csv("C:\\Users\\HARI\\Downloads\\labour_force.csv")
lab_prod_Ultilization=pd.read_csv("C:\\Users\\HARI\\Downloads\\lab_prod & ultization.csv")
GDP=pd.read_csv("C:\\Users\\HARI\\Downloads\GDP.csv")
inflation=pd.read_csv("C:\\Users\\HARI\\Downloads\\inflation.csv")
construction=pd.read_csv("C:\\Users\\HARI\\Downloads\\constructions.csv")
house_price=pd.read_csv("C:\\Users\\HARI\\Downloads\\CSUSHPISA.csv")
primary_energy=pd.read_csv("C:\\Users\\HARI\\Downloads\\primary_energy.csv")
renewable_energy=pd.read_csv("C:\\Users\\HARI\\Downloads\\renewable energy.csv")
crud_oil_price=pd.read_csv("C:\\Users\\HARI\\Downloads\\crud_oil_price1.csv")
interest_rates=pd.read_csv("C:\\Users\\HARI\\Downloads\\interest_rates.csv")
cons_conf_inde=pd.read_excel("C:\\Users\\HARI\\Downloads\\cons_conf_index.xlsx")
pub_sp_lab_mar=pd.read_csv("C:\\Users\\HARI\\Downloads\\pubsponlabour.csv")

# %%
interest_rates
# Out:
#    LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 0       USA     LTINT     TOT   PC_PA         A  2000  6.029167         NaN
# 1       USA     LTINT     TOT   PC_PA         A  2001  5.017500         NaN
# 2       USA     LTINT     TOT   PC_PA         A  2002  4.610833         NaN
# 3       USA     LTINT     TOT   PC_PA         A  2003  4.015000         NaN
# 4       USA     LTINT     TOT   PC_PA         A  2004  4.274167         NaN
# 5       USA     LTINT     TOT   PC_PA         A  2005  4.290000         NaN
# 6       USA     LTINT     TOT   PC_PA         A  2006  4.791667         NaN
# 7       USA     LTINT     TOT   PC_PA         A  2007  4.629167         NaN
# 8       USA     LTINT     TOT   PC_PA         A  2008  3.666667         NaN
# 9       USA     LTINT     TOT   PC_PA         A  2009  3.256667         NaN
# 10      USA     LTINT     TOT   PC_PA         A  2010  3.214167         NaN
# ...

# %%
employeement_rate=employeement_rate['Value']
hours_worked=hours_worked['Value']
labour_force=labour_force['Value']
lab_prod_Ultilization=lab_prod_Ultilization['Value']
GDP=GDP['Value']
inflation=inflation['Value']
construction=construction['Value']
house_price=house_price["CSUSHPISA"]
primary_energy=primary_energy['Value']
renewable_energy=renewable_energy['Value']
crud_oil_price=crud_oil_price[['Value','TIME']]
interest_rates=interest_rates['Value']
cons_conf_inde=cons_conf_inde['value']
pub_sp_lab_mar=pub_sp_lab_mar["Value"]

# %%
df=pd.concat([employeement_rate,hours_worked,labour_force,lab_prod_Ultilization,GDP,inflation,construction,house_price,primary_energy,renewable_energy,crud_oil_price,interest_rates,cons_conf_inde,pub_sp_lab_mar],axis=1)

# %%
df.columns=['employeement_rate','hours_worked','labour_force','lab_prod_Ultilization','GDP','inflation','construction','house_price','primary_energy','renewable_energy','crud_oil_price','Time','interest_rates','cons_conf_inde','pub_sp_lab_mar']

# %%
df
# Out:
#      employeement_rate  hours_worked  labour_force  lab_prod_Ultilization  \
# 0             74.09456   1879.845500      142582.6               2.746401
# 1             73.13562   1857.761250      143733.9               2.193970
# 2             71.92931   1854.013333      144862.9               2.766428
# 3             71.22334   1843.041667      146509.7               3.023780
# 4             71.22248   1844.062500      147401.2               2.616489
# ..                 ...           ...           ...                    ...
# 433                NaN           NaN           NaN                    NaN
# 434                NaN           NaN           NaN                    NaN
# 435                NaN           NaN           NaN                    NaN
# 436                NaN           NaN           NaN                    NaN
# 437                NaN           NaN           NaN                    NaN
#
#              GDP  inflation  construction  house_price  primary_energy  \
# ...

# %%
df=df.iloc[:23,:]

# %%
df
# Out:
#     employeement_rate  hours_worked  labour_force  lab_prod_Ultilization  \
# 0            74.09456   1879.845500      142582.6               2.746401
# 1            73.13562   1857.761250      143733.9               2.193970
# 2            71.92931   1854.013333      144862.9               2.766428
# 3            71.22334   1843.041667      146509.7               3.023780
# 4            71.22248   1844.062500      147401.2               2.616489
# 5            71.53017   1842.134250      149320.3               2.089042
# 6            71.99708   1843.688000      151427.6               0.946807
# 7            71.78132   1842.927500      153124.2               1.404249
# 8            70.88825   1829.389833      154286.7               1.280744
# 9            67.62595   1798.777500      154142.0               3.196011
# 10           66.68977   1810.387500      153888.6               2.642871
# 11           66.64754   1820.304167      153616.7               0.038302
# ...

# %%
df['primary_energy']=df['primary_energy'].fillna(df['primary_energy'].mean())
df['renewable_energy']=df['renewable_energy'].fillna(df['renewable_energy'].mean())
df['pub_sp_lab_mar']=df['pub_sp_lab_mar'].fillna(df['pub_sp_lab_mar'].mean())
# Out:
# C:\Users\HARI\AppData\Local\Temp\ipykernel_10476\12914059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['primary_energy']=df['primary_energy'].fillna(df['primary_energy'].mean())
# C:\Users\HARI\AppData\Local\Temp\ipykernel_10476\12914059.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['renewable_energy']=df['renewable_energy'].fillna(df['renewable_energy'].mean())
# C:\Users\HARI\AppData\Local\Temp\ipykernel_10476\12914059.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#     employeement_rate  hours_worked  labour_force  lab_prod_Ultilization  \
# 0            74.09456   1879.845500      142582.6               2.746401
# 1            73.13562   1857.761250      143733.9               2.193970
# 2            71.92931   1854.013333      144862.9               2.766428
# 3            71.22334   1843.041667      146509.7               3.023780
# 4            71.22248   1844.062500      147401.2               2.616489
# 5            71.53017   1842.134250      149320.3               2.089042
# 6            71.99708   1843.688000      151427.6               0.946807
# 7            71.78132   1842.927500      153124.2               1.404249
# 8            70.88825   1829.389833      154286.7               1.280744
# 9            67.62595   1798.777500      154142.0               3.196011
# 10           66.68977   1810.387500      153888.6               2.642871
# 11           66.64754   1820.304167      153616.7               0.038302
# ...

# %%
scaler = StandardScaler()

# Fit the scaler to the data and transform the data
standardized_data = scaler.fit_transform(df)

# %%
df.corr()
# Out:
#                        employeement_rate  hours_worked  labour_force  \
# employeement_rate               1.000000      0.762877     -0.441174
# hours_worked                    0.762877      1.000000     -0.773051
# labour_force                   -0.441174     -0.773051      1.000000
# lab_prod_Ultilization           0.092337      0.242973     -0.551746
# GDP                            -0.338696     -0.686450      0.958820
# inflation                       0.408856      0.119982      0.113061
# construction                    0.577663      0.044681      0.299802
# house_price                    -0.477349     -0.755923      0.976910
# primary_energy                  0.585889      0.734302     -0.915539
# renewable_energy               -0.545690     -0.654343      0.873103
# crud_oil_price                 -0.555765     -0.454969      0.433809
# Time                           -0.481092     -0.751326      0.975105
# interest_rates                  0.742993      0.790395     -0.819624
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
correlation_matrix = df.corr()
# Calculate the correlation with the target variable
target_correlation = correlation_matrix['house_price'].abs().sort_values(ascending=False)

# Select the top 5 features
top_N = 6
top_features = target_correlation.index[1:top_N+1]

# Use the selected features
selected_data = df[top_features]

# %%
selected_data
# Out:
#       Time          GDP  labour_force  primary_energy  renewable_energy  \
# 0   2000.0  36299.66218      142582.6        0.165000          4.490000
# 1   2001.0  37100.28574      143733.9        0.161000          4.000000
# 2   2002.0  37954.22201      144862.9        0.160000          4.050000
# 3   2003.0  39419.90737      146509.7        0.156000          4.300000
# 4   2004.0  41659.66269      147401.2        0.153000          4.400000
# 5   2005.0  44052.38300      149320.3        0.149000          4.540000
# 6   2006.0  46234.10571      151427.6        0.143000          4.770000
# 7   2007.0  47976.20121      153124.2        0.143000          4.670000
# 8   2008.0  48498.44521      154286.7        0.139000          5.070000
# 9   2009.0  47122.98854      154142.0        0.136000          5.440000
# 10  2010.0  48570.28973      153888.6        0.135000          5.680000
# 11  2011.0  49951.90765      153616.7        0.131000          6.190000
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['house_price'], df['cons_conf_inde'])
plt.xticks(rotation=45)
plt.xlabel('House_Price')
plt.ylabel('cons_conf_index')
plt.title('Line Plot between House_price and cons_conf_index')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.xticks(rotation=45)
plt.plot(df['house_price'], df['GDP'])
plt.xlabel('house_price')
plt.ylabel('Value')
plt.title('Line Plot between house_price and GDP')
plt.show()

# %%
# Create a figure and axis

fig, ax = plt.subplots()

# Plot the first line
ax.plot(df['GDP'], df['house_price'], label='Line 1', linestyle='-', marker='o', color='blue')

# Plot the second line
ax.plot(df['labour_force'], df['house_price'], label='Line 2', linestyle='--', marker='s', color='green')

# Plot the third line
ax.plot(df['renewable_energy'], df['house_price'], label='Line 3', linestyle='-.', marker='^', color='red')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Multiple Line Chart')

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
X=df.drop('house_price',axis=1)
y=df['house_price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
mae = mean_absolute_error(y, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.016425668303519412

# %%
r2 = r2_score(y, y_pred)
print("R-squared (R²) Score:", r2)
# Out:
# R-squared (R²) Score: 0.9999417452760591

# %%
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.0004314622517565773
